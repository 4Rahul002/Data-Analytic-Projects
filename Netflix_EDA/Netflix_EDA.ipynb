# %% [markdown]
# <a href="https://colab.research.google.com/github/4Rahul002/Data-Analytic-Projects/blob/main/Netflix_EDA/Netflix_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Netflix Dataset EDA

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 - Rahul M Chavan**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project explores a dataset containing information on Netflix’s TV shows and movies. Netflix, being a major player in the streaming industry, offers a wide range of content across genres, countries, and formats. Understanding the distribution, composition, and patterns in this data can guide content strategy, viewer targeting, and business decisions.
#
# The dataset has 7,787 entries with 12 columns. Key attributes include type, title, director, cast, country, release_year, rating, duration, listed_in, and description. Some data cleaning was required due to missing values and categorical inconsistencies.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/4Rahul002/Data-Analytic-Projects/tree/main/Netflix_EDA

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
#
# Netflix offers a vast catalog of content, but lacks structured insights on content trends over time, popular genres by region, and the evolving nature of TV vs. Movies. There is a need to analyze what content performs best by year, genre, and country, and what kind of shows or movies Netflix should produce more of.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Understand trends in content type (TV vs Movie).
#
# Identify most frequent genres and their performance.
#
# Analyze content distribution by country and year.
#
# Find missing or underutilized segments for future targeting.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
np.random.seed(42)

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Labmetnix_PRoject_EDA/Netflix_EDA/NETFLIX MOVIES AND TV SHOWS CLUSTERING.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head(10)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
# 7      s8    Movie    187     Kevin Reynolds
# 8      s9    Movie    706      Shravan Kumar
# 9     s10    Movie   1920       Vikram Bhatt
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
df['title'].to_list()
# Out:
# ['3%',
#  '7:19',
#  '23:59',
#  '9',
#  '21',
#  '46',
#  '122',
#  '187',
#  '706',
#  '1920',
#  '1922',
#  '1983',
#  '1994',
#  '2,215',
#  '3022',
#  'Oct-01',
#  'Feb-09',
#  '22-Jul',
#  '15-Aug',
#  "'89",
#  '\u200b\u200bKuch Bheege Alfaaz',
#  '\u200bGoli Soda 2',
#  '\u200bMaj Rati \u200b\u200bKeteki',
#  '\u200bMayurakshi',
#  '\u200bSAINT SEIYA: Knights of the Zodiac',
#  '(T)ERROR',
#  '(Un)Well',
#  '#Alive',
#  '#AnneFrank - Parallel Stories',
#  '#blackAF',
#  '#cats_the_mewvie',
#  '#FriendButMarried',
#  '#FriendButMarried 2',
#  '#realityhigh',
#  '#Roxy',
#  '#Rucker50',
#  '#Selfie',
#  '#Selfie 69',
#  'แผนร้ายนายเจ้าเล่ห์',
#  '¡Ay, mi madre!',
#  'Çarsi Pazar',
#  'Ég man þig',
#  'Çok Filim Hareketler Bunlar',
#  'Òlòtūré',
#  'Æon Flux',
#  'Şubat',
#  '1 Chance 2 Dance',
#  '1 Mile to You',
#  '10 Days in Sun City',
#  '10 jours en or',
#  '10,000 B.C.',
#  '100 Days My Prince',
#  '100 Days Of Solitude',
#  '100 Humans',
#  '100 Meters',
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (7787, 12)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().any()
# Out:
# np.False_

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df['director'].value_counts()
df["cast"].value_counts()
df["country"].value_counts()
#df["date_added"].value_counts()
#df["rating"].value_counts()
# Out:
# country
# United States                                                 2555
# India                                                          923
# United Kingdom                                                 397
# Japan                                                          226
# South Korea                                                    183
#                                                               ...
# Canada, United States, India, United Kingdom                     1
# United States, Brazil, South Korea, Mexico, Japan, Germany       1
# France, Lebanon, United Kingdom                                  1
# United Kingdom, Jordan, Qatar, Iran                              1
# Switzerland, United Kingdom, United States                       1
# Name: count, Length: 681, dtype: int64

# %%
# Fill missing string values with 'Not Available'
df['director'].fillna('Not Available', inplace=True)
df['cast'].fillna('Not Available', inplace=True)
df['country'].fillna('Not Available', inplace=True)
df['rating'].fillna('Not Rated', inplace=True)

# For date_added, we can drop or fill with mode
df['date_added'].fillna(df['date_added'].mode()[0], inplace=True)

# %%
import datetime as dt
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
df['year_added'] = df['date_added'].dt.year
df['duration_int'] = df['duration'].str.extract('(\d+)').astype(float)
df['duration_type'] = df['duration'].str.extract('([a-zA-Z]+)')

# %%
# Visualizing the missing values
plt.figure(figsize=(10,6))
sns.barplot(x=df.columns, y=df.isnull().sum())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The shape of the Dataset is 7787 rows and 12 columns
# There are no Duplicates
#
# But a lot missing values
# director	2389
# cast	718
# country	507
# date_added	10
# release_year	0
# rating	7
#
# filled all of them with Not avaiable except date_added with Mode value
#
# Added 2 columns duration_int(integer) and duration_type(movie or tv show).

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns.to_list()
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'release_year',
#  'rating',
#  'duration',
#  'listed_in',
#  'description',
#  'duration_int',
#  'duration_type']

# %%
# Dataset Describe
df.describe()
# Out:
#        release_year  duration_int
# count   7787.000000   7787.000000
# mean    2013.932580     69.122769
# std        8.757395     50.950743
# min     1925.000000      1.000000
# 25%     2013.000000      2.000000
# 50%     2017.000000     88.000000
# 75%     2018.000000    106.000000
# max     2021.000000    312.000000

# %%
df.describe(include='object')
# Out:
#        show_id   type                                    title       director  \
# count     7787   7787                                     7787           7787
# unique    7787      2                                     7787           4050
# top      s7787  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  Not Available
# freq         1   5377                                        1           2389
#
#                  cast        country       date_added rating  duration  \
# count            7787           7787             7787   7787      7787
# unique           6832            682             1565     15       216
# top     Not Available  United States  January 1, 2020  TV-MA  1 Season
# freq              718           2555              128   2863      1608
#
#             listed_in                                        description  \
# count            7787                                               7787
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# show_id: unique identifier
#
# type: Movie or TV Show
#
# title: name of the content
#
# director, cast: creators and actors
#
# country: production country
#
# date_added: when added to Netflix
#
# release_year: when it was released
#
# rating: age/parental rating
#
# duration: time or seasons
#
# listed_in: genres
#
# description: summary

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# show_id          7787
# type                2
# title            7787
# director         4050
# cast             6832
# country           682
# date_added       1565
# release_year       73
# rating             15
# duration          216
# listed_in         492
# description      7769
# duration_int      206
# duration_type       3
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
sns.set_style('whitegrid')

# %%
# Write your code to make your dataset analysis ready.
# Check for outliers
plt.figure(figsize=(10,6))
sns.boxplot(df)
plt.title('Outlier identification')
plt.show()

# %%
from scipy.stats.mstats import winsorize
import seaborn as sns
import matplotlib.pyplot as plt

# Apply Winsorization to 'duration_int' column (cap top & bottom 1%)
df['duration_winsorized'] = winsorize(df['duration_int'], limits=[0.01, 0.01])

# Apply Winsorization to 'release_year' column if needed
df['release_year_winsorized'] = winsorize(df['release_year'], limits=[0.01, 0.01])

# %%
#After winsorization
plt.figure(figsize=(10,6))
sns.boxplot(df)
plt.title('Outlier identification')
plt.show()

# %% [markdown]
# ## After capping extreme values , we have better data with less outliers

# %%
sns.boxplot(data=df, x='type', y='duration_winsorized')
plt.title("Boxplot of Duration by Type (Winsorized)")
plt.xlabel("Type")
plt.ylabel("Duration (winsorized)")
plt.show()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# This shows distribution here
#
# We see that TV show seasons Ranges from 1 to 15
#
# Movies have  Ranges High and low but ideally or averages around 50- 157 min

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Content type distribution
sns.countplot(data=df, x='type')
plt.title("Distribution of Content Type")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To see if Netflix has more movies or TV shows we use countplot for better comparison

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Movies dominate the platform (~70%)

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Movies make more in revenue than a Tv show can ever do ,but by producing better and award worthy Tv shows that increase the viewer count

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
#Top 10 countries by content
df['country'].value_counts().head(10).plot(kind='bar')
plt.title("Top 10 Countries by Number of Titles")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Ideal Chart like barplot to Identify content-producing regions

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# USA has the highest number of titles

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Rating distribution
sns.countplot(data=df, x='rating', order=df['rating'].value_counts().head(10).index)
plt.title("Top 10 Ratings")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ideal Chart for Understanding audience segmentation

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# TV-MA and TV-14 are the most common ratings

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Release year histogram
sns.histplot(data=df, x='release_year', bins=30, kde=True)
plt.title("Content Release Year Distribution")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# using Histogram that shows distribution to Observe content trends over years

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Peak content release between 2018–2020

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Top 10 genres
genres = df['listed_in'].str.split(', ').explode()
genres.value_counts().head(10).plot(kind='bar')
plt.title("Top 10 Genres")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# using Barplot to find the most common genre Identify popular genres

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Dramas and Comedies dominate , international movies too but is not one of the Genres

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
#Type vs Rating
sns.countplot(data=df, x='rating', hue='type', order=df['rating'].value_counts().head(10).index)
plt.title("Type vs Rating")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Countplot does Compare rating distribution by content type

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Movies mostly rated TV-MA ,Shows lean trend TV-14

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Content added per year
sns.lineplot(df['year_added'].value_counts().sort_index(),marker='o')
plt.xlabel('Year Added')
plt.ylabel('Number of Titles')
plt.title("Content Added to Netflix Per Year")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Line Chart ideal for time series data to Track upload trend

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Spike in 2019-2020, slight dip in 2021

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Country vs Type
top_countries = df['country'].value_counts().head(10).index
df_top = df[df['country'].isin(top_countries)]
sns.countplot(data=df_top, x='country', hue='type', order=top_countries)
plt.title("Type Distribution in Top 10 Countries")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Countplot shows categorical data  , Type preference by country

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# India leans more toward movies , because of its many Bollywood,Kollywood,Tollywood movies and few Tv shows

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There are Tv shows in india that produced only for drama addict , lately there are few shows that are doing better .
#
# Making better shows effectively bring a Rise in viewers

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Duration by type
sns.boxplot(data=df, x='type', y='duration_int')
plt.title("Duration Comparison Between Types")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Compare average duration

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Movies vary more in duration than TV Shows

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Cluster-style type-country chart
sns.countplot(data=df[df['country'].isin(['United States', 'India', 'United Kingdom'])], x='country', hue='type')
plt.title("Type Distribution in Key Countries")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Deeper look at top 3 countries

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  US and UK have more balanced content, India = Movie-heavy

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Top 5 directors (Pie)
filtered_df=df[df['director']!="Not Available"]
top_directors = filtered_df['director'].value_counts().head(5)
top_directors.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title("Top 5 Directors")
plt.ylabel("")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  See which directors dominate

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  No single director dominates—very fragmented

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# !pip install wordcloud
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.9/547.9 kB 7.7 MB/s eta 0:00:00
# ...

# %%
# Chart - 12 visualization code
# Word Cloud of Descriptions
from wordcloud import WordCloud

text = ' '.join(df['description'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Description Word Cloud")
plt.show()
# Reason: Get feel of content themes
# Insight: Common words: "life", "love", "family", "murder" etc.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Word cloud used to Get feel of content themes

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Common words: "life", "love", "family", "murder" etc.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Average Duration by Genre (for Movies only)
movie_df = df[df['type'] == 'Movie']
genre_duration = movie_df.assign(genre=movie_df['listed_in'].str.split(', ')).explode('genre')
genre_avg_duration = genre_duration.groupby('genre')['duration_int'].mean().sort_values(ascending=False).head(10)
genre_avg_duration.plot(kind='bar', color='coral')
plt.title("Top 10 Genres by Average Duration (Movies)")
plt.xlabel("Genre")
plt.ylabel("Average Duration (min)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Identify which movie genres tend to be longer

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Classical Movies and Dramas have higher average durations

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Correlation heatmap
sns.heatmap(df[['release_year', 'duration_int']].corr(), annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Spot correlation between numeric fields

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Very weak correlation between year and duration

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
df_numeric = df[['release_year', 'duration_int']]
sns.pairplot(df_numeric)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To explore pairwise relationships visually

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most movies cluster around recent years with short durations

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# A data-driven exploratory analysis using Python libraries like Pandas, Seaborn, and Matplotlib was conducted. The dataset was cleaned, and visualizations were created based on:
#
# Univariate analysis: distribution of single variables
#
# Bivariate analysis: relationships between two variables
#
# Multivariate analysis: more complex interactions

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This Netflix dataset reveals strategic opportunities for content curation. Genres like Documentaries and Dramas dominate, and the U.S. is Netflix’s largest content base. Analysis suggests investing more in regional content and exploring underutilized genres like Anime in non-Asian countries. Using such analysis, Netflix can tailor its expansion and production plans efficiently.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
